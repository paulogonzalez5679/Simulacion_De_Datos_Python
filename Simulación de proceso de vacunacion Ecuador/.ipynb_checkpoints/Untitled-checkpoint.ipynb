# %% [markdown]
# # Práctica Sympy 2

# %% [markdown]
# Generar un modelo de simulación para el proceso de vacunación del Covid. Para ello se debe investigar algun recinto de vacunación con el objetivo de generar métricas en base a los siguientes datos:
# - Personal de vacunación
# - Número de personas llamadas
# - Otro parámetros
#
# El proceso de vacunación es el siguiente:
# - Ingresa a la fila a que le toque su turno.
# - Tenemos un proceso de control en donde se toma los signos vitales y se valida que esté dentro del padrón (2-5 minutos).
# - Como ejemplificación menos del 5% no es vacunada ya que presenta signos de alerta.
# - Se procede al traslado a la silla de vacunación y se inyecta la dosis de la vacuna (5-10 minutos).
# - Finalmente son llevados a la salida (1-3 minutos).
#
#
# Finalmente generar las siguientes métricas/gráficas:
# - Tiempo de espera promedio para cada persona.
# - Tiempo promedio total que requiere un paciente para ser vacunado.
# - Cuántos pacientes se atendieron.
# - Cuántos pacientes se quedaron sin atender.

# %%
import simpy
import random
import matplotlib.pyplot as pp
import math

# %%
# Personal de vacunación
PERSONAL = 20
# Intervalo de tiempo en el que llegan las personas (minutos)
INTERVALO_LLEGADA = 20
# Intervalo de control de una persona 
INTERVALO_CONTROL = 3
# Intervalo vacunación (minutos)
INTERVALO_VACUNACION = 8
# Intervalo de tiempo en el que una persona sale del centro de vacunación
INTERVALO_SALIDA = 2
# Tiempo de simulación
TIEMPO_SIMULACION = 100
# Cantidad de vacunados
CANTIDAD_VACUNADOS = 0
# Cantidad de personas que llegaron
CANTIDAD_PERSONAS = 0
# Tiempo Vacunación
TIEMPOVACUNACION = 0
# Tiempo Espera
TIEMPOESPERA = 0
# Tiempo de vacunación de cada persona
TIEMPOVACUNACIONDICT = {}
# Tiempo de espera de cada persona
TIEMPOESPERADICT = {}

# %%
class Vacunacion(object):

    def __init__(self, environment, cantPersonal, tiempoVacunacion, tiempoControl, tiempoSalida):
        self.env = environment
        #Creamos el recurso del personal o puestos de vacunación
        self.personal = simpy.Resource(environment, cantPersonal)
        self.tiempoControl = tiempoControl
        self.tiempoVacunacion = tiempoVacunacion
        self.tiempoSalida = tiempoSalida

    def controlPersona(self):
        yield self.env.timeout(random.randint(self.tiempoControl-1, self.tiempoControl+2))
        
    def vacunar_persona(self, persona):
        yield self.env.timeout(random.randint(self.tiempoVacunacion-3, self.tiempoVacunacion+2))
        
    def salidaPersona(self):
        yield self.env.timeout(random.randint(self.tiempoSalida-1, self.tiempoSalida+1))

        
def conteoVacunados():
    global CANTIDAD_VACUNADOS
    CANTIDAD_VACUNADOS +=1

def conteoPersonas():
    global CANTIDAD_PERSONAS
    CANTIDAD_PERSONAS +=1
    
def tiempoEspera(persona, tiempoEspera):
    global TIEMPOESPERA
    global TIEMPOESPERADICT
    # Agregamos al diccionario el tiempo de espera por persona
    TIEMPOESPERADICT[persona.split('-')[1]] = tiempoEspera
    # Se obtiene el tiempo total de espera de todas las personas
    TIEMPOESPERA += tiempoEspera
    
def tiempoVacunacion(persona, tiempoPersona):
    global TIEMPOVACUNACION 
    global TIEMPOVACUNACIONDICT
    # Agregamos al diccionario el tiempo de vacunación por persona
    TIEMPOVACUNACIONDICT[persona.split('-')[1]] = tiempoPersona
    # Se obtiene el tiempo total de vacunación de todas las personas
    TIEMPOVACUNACION += tiempoPersona
    

def llegada_persona(env, nombre, vacunacion):
    # Usamos el reloj de la simulacion (env.now()) para indicar a la
    # hora que llega una persona con el nombre pasado como parametro
    print(' → Llega persona: %s a la hora %.2f.' % (nombre, env.now))
    
    # Inicio del proceso
    inicioEspera = env.now
    
    # La persona tarda 1 minuto hasta llegar al control
    yield env.timeout(1)
    print('La persona: %s entra al control a la hora %.2f.' % (nombre, env.now))
    
    # Indicamos que la persona entra en el proceso de control
    yield env.process(vacunacion.controlPersona())
    print('La persona: %s sale control a la hora %.2f.' % (nombre, env.now))
    
    # Despues del control se cumple con que solo el 5% de las personas 
    # no cumplen con las condiciones para ser vacunadas
    rnd = random.randint(1,100)
    if rnd <= 5:
        print('La persona [%s] no cumple con los requerimientos'%(nombre))
    else:
        # Especificamos que vamos a usar un recurso (Resource) que representa
        # un doctor
        with vacunacion.personal.request() as doctor:
            # Se ocupa un doctor para la vacunación de una persona.
            yield doctor
            
            #Indicamos que la persona entra en el proceso de vacunación
            print('Se traslada %s a la silla de vacunación a la hora %.2f.' % (nombre,env.now))
    
            # Inicia el tiempo de la vacunación
            inicio = env.now
    
            # Procesamos la aplicación de la vacuna
            yield env.process(vacunacion.vacunar_persona(nombre))
            
            # Se registra otra persona vacunada
            conteoVacunados()
            
            # Obtener el tiempo total de la vacunación de una persona
            tiempoVacunacion(nombre, env.now-inicio)
            
            # Una vez que termina la llamada con 'yield', se indica que se ha vacunado la persona
            print('La [%s] fue vacunada a las %.2f.' % (nombre, env.now)) 
                      
            # Obtener el tiempo total de espera de una persona
            tiempoEspera(nombre, env.now-inicioEspera)
            
            # La persona despues de ser vacuna sale del centro de vacunación
            yield env.process(vacunacion.salidaPersona())
            print('La persona [%s] sale del centro a las %.2f.' % (nombre, env.now)) 
            
            
        
def ejecutar_simulacion(env, cantPersonal, tiempoVacunacion, tiempoControl, tiempoSalida):
    vacunacion=Vacunacion(env, cantPersonal, tiempoVacunacion, tiempoControl, tiempoSalida)
    
    # Creamos 5 persona que llegan
    for i in range(5):
        conteoPersonas()
        env.process(llegada_persona(env, 'Persona-%d'%(i+1), vacunacion))
        
        
    # Ejecutamos la simulacion
    while True:
        yield env.timeout(5)
        i+=1
        conteoPersonas()
        env.process(llegada_persona(env,'Persona-%d'%(i+1), vacunacion))  
    

print('Proceso/tiempo de Vacunación')
# Creamos el entorno de simulacion
env=simpy.Environment()
env.process(ejecutar_simulacion(env, PERSONAL, INTERVALO_VACUNACION,INTERVALO_CONTROL, INTERVALO_SALIDA))
# Ejecutamos el proceso durante el tiempo de simulacion
env.run(until = TIEMPO_SIMULACION)
# Out:
# Proceso/tiempo de Vacunación
#  → Llega persona: Persona-1 a la hora 0.00.
#  → Llega persona: Persona-2 a la hora 0.00.
#  → Llega persona: Persona-3 a la hora 0.00.
#  → Llega persona: Persona-4 a la hora 0.00.
#  → Llega persona: Persona-5 a la hora 0.00.
# La persona: Persona-1 entra al control a la hora 1.00.
# La persona: Persona-2 entra al control a la hora 1.00.
# La persona: Persona-3 entra al control a la hora 1.00.
# La persona: Persona-4 entra al control a la hora 1.00.
# La persona: Persona-5 entra al control a la hora 1.00.
# La persona: Persona-2 sale control a la hora 4.00.
# La persona: Persona-3 sale control a la hora 4.00.
# La persona: Persona-4 sale control a la hora 4.00.
# Se traslada Persona-2 a la silla de vacunación a la hora 4.00.
# Se traslada Persona-3 a la silla de vacunación a la hora 4.00.
# Se traslada Persona-4 a la silla de vacunación a la hora 4.00.
#  → Llega persona: Persona-6 a la hora 5.00.
# La persona: Persona-1 sale control a la hora 5.00.
# Se traslada Persona-1 a la silla de vacunación a la hora 5.00.
# La persona: Persona-6 entra al control a la hora 6.00.
# La persona: Persona-5 sale control a la hora 6.00.
# Se traslada Persona-5 a la silla de vacunación a la hora 6.00.
# La [Persona-4] fue vacunada a las 9.00.
# La persona: Persona-6 sale control a la hora 9.00.
# Se traslada Persona-6 a la silla de vacunación a la hora 9.00.
#  → Llega persona: Persona-7 a la hora 10.00.
# La persona: Persona-7 entra al control a la hora 11.00.
# La persona [Persona-4] sale del centro a las 11.00.
# La [Persona-3] fue vacunada a las 12.00.
# La [Persona-5] fue vacunada a las 12.00.
# La persona [Persona-5] sale del centro a las 13.00.
# La [Persona-2] fue vacunada a las 14.00.
# La [Persona-1] fue vacunada a las 14.00.
#  → Llega persona: Persona-8 a la hora 15.00.
# La persona: Persona-7 sale control a la hora 15.00.
# La persona [Persona-3] sale del centro a las 15.00.
# Se traslada Persona-7 a la silla de vacunación a la hora 15.00.
# La persona: Persona-8 entra al control a la hora 16.00.
# La persona [Persona-2] sale del centro a las 16.00.
# La [Persona-6] fue vacunada a las 17.00.
# La persona [Persona-1] sale del centro a las 17.00.
# La persona [Persona-6] sale del centro a las 18.00.
#  → Llega persona: Persona-9 a la hora 20.00.
# La persona: Persona-9 entra al control a la hora 21.00.
# La persona: Persona-8 sale control a la hora 21.00.
# Se traslada Persona-8 a la silla de vacunación a la hora 21.00.
# La [Persona-7] fue vacunada a las 22.00.
# La persona: Persona-9 sale control a la hora 23.00.
# Se traslada Persona-9 a la silla de vacunación a la hora 23.00.
# La persona [Persona-7] sale del centro a las 24.00.
#  → Llega persona: Persona-10 a la hora 25.00.
# La persona: Persona-10 entra al control a la hora 26.00.
# La [Persona-8] fue vacunada a las 28.00.
# La persona: Persona-10 sale control a la hora 28.00.
# Se traslada Persona-10 a la silla de vacunación a la hora 28.00.
#  → Llega persona: Persona-11 a la hora 30.00.
# La persona: Persona-11 entra al control a la hora 31.00.
# La persona [Persona-8] sale del centro a las 31.00.
# La [Persona-9] fue vacunada a las 33.00.
# La persona: Persona-11 sale control a la hora 34.00.
# Se traslada Persona-11 a la silla de vacunación a la hora 34.00.
#  → Llega persona: Persona-12 a la hora 35.00.
# La persona [Persona-9] sale del centro a las 35.00.
# La persona: Persona-12 entra al control a la hora 36.00.
# La [Persona-10] fue vacunada a las 37.00.
#  → Llega persona: Persona-13 a la hora 40.00.
# La persona: Persona-12 sale control a la hora 40.00.
# La persona [Persona-10] sale del centro a las 40.00.
# Se traslada Persona-12 a la silla de vacunación a la hora 40.00.
# La persona: Persona-13 entra al control a la hora 41.00.
# La [Persona-11] fue vacunada a las 42.00.
# La persona: Persona-13 sale control a la hora 44.00.
# La persona [Persona-11] sale del centro a las 44.00.
# Se traslada Persona-13 a la silla de vacunación a la hora 44.00.
#  → Llega persona: Persona-14 a la hora 45.00.
# La [Persona-12] fue vacunada a las 45.00.
# La persona: Persona-14 entra al control a la hora 46.00.
# La persona [Persona-12] sale del centro a las 46.00.
# La [Persona-13] fue vacunada a las 49.00.
#  → Llega persona: Persona-15 a la hora 50.00.
# La persona: Persona-15 entra al control a la hora 51.00.
# La persona: Persona-14 sale control a la hora 51.00.
# La persona [Persona-13] sale del centro a las 51.00.
# Se traslada Persona-14 a la silla de vacunación a la hora 51.00.
#  → Llega persona: Persona-16 a la hora 55.00.
# La persona: Persona-15 sale control a la hora 55.00.
# La persona [Persona-15] no cumple con los requerimientos
# La persona: Persona-16 entra al control a la hora 56.00.
# La [Persona-14] fue vacunada a las 57.00.
# La persona: Persona-16 sale control a la hora 58.00.
# Se traslada Persona-16 a la silla de vacunación a la hora 58.00.
# La persona [Persona-14] sale del centro a las 59.00.
#  → Llega persona: Persona-17 a la hora 60.00.
# La persona: Persona-17 entra al control a la hora 61.00.
# La persona: Persona-17 sale control a la hora 63.00.
# Se traslada Persona-17 a la silla de vacunación a la hora 63.00.
# La [Persona-16] fue vacunada a las 64.00.
#  → Llega persona: Persona-18 a la hora 65.00.
# La persona: Persona-18 entra al control a la hora 66.00.
# La persona [Persona-16] sale del centro a las 67.00.
# La [Persona-17] fue vacunada a las 68.00.
# La persona [Persona-17] sale del centro a las 69.00.
#  → Llega persona: Persona-19 a la hora 70.00.
# La persona: Persona-18 sale control a la hora 70.00.
# Se traslada Persona-18 a la silla de vacunación a la hora 70.00.
# La persona: Persona-19 entra al control a la hora 71.00.
# La persona: Persona-19 sale control a la hora 73.00.
# La persona [Persona-19] no cumple con los requerimientos
#  → Llega persona: Persona-20 a la hora 75.00.
# La persona: Persona-20 entra al control a la hora 76.00.
# La [Persona-18] fue vacunada a las 78.00.
# La persona: Persona-20 sale control a la hora 79.00.
# La persona [Persona-18] sale del centro a las 79.00.
# Se traslada Persona-20 a la silla de vacunación a la hora 79.00.
#  → Llega persona: Persona-21 a la hora 80.00.
# La persona: Persona-21 entra al control a la hora 81.00.
#  → Llega persona: Persona-22 a la hora 85.00.
# La persona: Persona-22 entra al control a la hora 86.00.
# La persona: Persona-21 sale control a la hora 86.00.
# Se traslada Persona-21 a la silla de vacunación a la hora 86.00.
# La [Persona-20] fue vacunada a las 88.00.
# La persona: Persona-22 sale control a la hora 89.00.
# La persona [Persona-20] sale del centro a las 89.00.
# Se traslada Persona-22 a la silla de vacunación a la hora 89.00.
#  → Llega persona: Persona-23 a la hora 90.00.
# La persona: Persona-23 entra al control a la hora 91.00.
# La persona: Persona-23 sale control a la hora 93.00.
# Se traslada Persona-23 a la silla de vacunación a la hora 93.00.
# La [Persona-22] fue vacunada a las 94.00.
#  → Llega persona: Persona-24 a la hora 95.00.
# La persona: Persona-24 entra al control a la hora 96.00.
# La [Persona-21] fue vacunada a las 96.00.
# La persona [Persona-22] sale del centro a las 97.00.
# La persona [Persona-21] sale del centro a las 98.00.

# %%
 print('Total de Personas:', CANTIDAD_PERSONAS, '\n')
print('Total Vacunados:', CANTIDAD_VACUNADOS, '\n')
print('Total No Vacunados:', CANTIDAD_PERSONAS-CANTIDAD_VACUNADOS, '\n')
print('Tiempo de vacunación promedio: ', round(TIEMPOVACUNACION/CANTIDAD_VACUNADOS, 2), '\n')
print('Tiempo de espera promedio: ', round(TIEMPOESPERA/CANTIDAD_VACUNADOS, 2), '\n')
print('Tiempo total de vacunación: ', TIEMPOVACUNACION, '\n')
# Out:
# Total de Personas: 24
#
# Total Vacunados: 20
#
# Total No Vacunados: 4
#
# Tiempo de vacunación promedio:  7.3
#
# Tiempo de espera promedio:  11.7
#
# Tiempo total de vacunación:  146

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (15,7))

plt.title("Tiempo de vacunación por persona")
plt.xlabel("Persona")
plt.ylabel("Tiempo")

#list(TIEMPOVACUNACIONDICT.keys())
plt.plot(range(len(TIEMPOVACUNACIONDICT)), list(TIEMPOVACUNACIONDICT.values()), '.-', label='Tiempo Vacunacion', color='cornflowerblue')

plt.axhline(y=TIEMPOVACUNACION/CANTIDAD_VACUNADOS, color='gray', linestyle='--')

plt.grid(axis='x')

plt.legend(loc="upper left")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (15,7))

plt.title("Tiempo de espera por persona")
plt.xlabel("Persona")
plt.ylabel("Tiempo")

#list(TIEMPOESPERADICT.keys())
plt.plot(range(len(TIEMPOESPERADICT)), list(TIEMPOESPERADICT.values()), '.-', label='Tiempo Espera', color='darkblue')

plt.axhline(y=TIEMPOESPERA/CANTIDAD_VACUNADOS, color='gray', linestyle='--')

plt.grid(axis='x')

plt.legend(loc="upper left")

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3]

tags = ['Asistentes','Vacunados', 'No Vacunados']

fig, ax = plt.subplots(figsize=(10,5))
rects1 = ax.bar(x[0], CANTIDAD_PERSONAS, 0.25, label='Asistentes', color="#007CC2")
rects2 = ax.bar(x[1], CANTIDAD_VACUNADOS, 0.25, label='Vacunados', color='#1ABC9C')
rects3= ax.bar(x[2], CANTIDAD_PERSONAS-CANTIDAD_VACUNADOS, 0.25, label='No Vacunados', color="#D70006")

ax.set_ylabel('Cantidad de personas')
ax.set_title('Asistencia al centro de vacunación')
ax.set_xticks(x)
ax.set_xticklabels(tags)
ax.legend(loc="upper right")

plt.show()
